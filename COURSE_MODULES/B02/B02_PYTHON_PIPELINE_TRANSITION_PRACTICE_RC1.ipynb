# %% [markdown]
# # B02 Python Pipeline Transition - Independent Practice RC1
# **Rule:** save genuine attempt before protected review. Follow -> reproduce -> change -> debug -> validate -> explain. External media is optional.

# %% [markdown]
# ## P-B02-L01 - Script contract
#
# **Your task:** Build clean-start main(input_path, output_path); source/output row-count check; then changed month/output path.
#
# Before code, write: input/output grain or file contract, critical failure rule, expected validation. After code, save observed result, one changed retry, one failure/recovery note and 60-90 second explain-back.

# %%
# YOUR GENUINE ATTEMPT
# Save this before opening the protected review.

# %% [markdown]
# ## P-B02-L02 - Functions/modules
#
# **Your task:** Split load/transform/validate/publish; missing-column fixture must fail with contextual message.
#
# Before code, write: input/output grain or file contract, critical failure rule, expected validation. After code, save observed result, one changed retry, one failure/recovery note and 60-90 second explain-back.

# %%
# YOUR GENUINE ATTEMPT
# Save this before opening the protected review.

# %% [markdown]
# ## P-B02-L03 - Deterministic multi-file batch
#
# **Your task:** Sorted glob of monthly sales; source_file lineage; per-file schema and 32+32+32=96 reconciliation.
#
# Before code, write: input/output grain or file contract, critical failure rule, expected validation. After code, save observed result, one changed retry, one failure/recovery note and 60-90 second explain-back.

# %%
# YOUR GENUINE ATTEMPT
# Save this before opening the protected review.

# %% [markdown]
# ## P-B02-L04 - Merge contract
#
# **Your task:** Prove supplied customer master is invalid (31 rows/30 unique/C013); many_to_one must block; no silent dedupe.
#
# Before code, write: input/output grain or file contract, critical failure rule, expected validation. After code, save observed result, one changed retry, one failure/recovery note and 60-90 second explain-back.

# %%
# YOUR GENUINE ATTEMPT
# Save this before opening the protected review.

# %% [markdown]
# ## P-B02-L05 - CSV/JSON/Excel interfaces
#
# **Your task:** CSV schema; nested JSON 5 orders/10 items; preserve template; output must be separate and validated if Excel writer available.
#
# Before code, write: input/output grain or file contract, critical failure rule, expected validation. After code, save observed result, one changed retry, one failure/recovery note and 60-90 second explain-back.

# %%
# YOUR GENUINE ATTEMPT
# Save this before opening the protected review.

# %% [markdown]
# ## P-B02-L06 - API basics
#
# **Your task:** Offline api_response.json validation first; optional local HTTP GET with timeout/status; exactly four metrics.
#
# Before code, write: input/output grain or file contract, critical failure rule, expected validation. After code, save observed result, one changed retry, one failure/recovery note and 60-90 second explain-back.

# %%
# YOUR GENUINE ATTEMPT
# Save this before opening the protected review.

# %% [markdown]
# ## P-B02-L07 - Failure classification
#
# **Your task:** Bad numeric order 1006 + missing customer_id fixture; classify, contain, prove publish withheld.
#
# Before code, write: input/output grain or file contract, critical failure rule, expected validation. After code, save observed result, one changed retry, one failure/recovery note and 60-90 second explain-back.

# %%
# YOUR GENUINE ATTEMPT
# Save this before opening the protected review.

# %% [markdown]
# ## P-B02-L08 - Logging + validation gate
#
# **Your task:** Create run.log + validation_results.json; critical customer-key FAIL must block publish; add net total check.
#
# Before code, write: input/output grain or file contract, critical failure rule, expected validation. After code, save observed result, one changed retry, one failure/recovery note and 60-90 second explain-back.

# %%
# YOUR GENUINE ATTEMPT
# Save this before opening the protected review.

# %% [markdown]
# ## P-B02-L09 - Safe rerun
#
# **Your task:** Two unchanged good-path rehearsal runs: same business rows/totals; raw hashes unchanged; failed validation cannot overwrite prior good output.
#
# Before code, write: input/output grain or file contract, critical failure rule, expected validation. After code, save observed result, one changed retry, one failure/recovery note and 60-90 second explain-back.

# %%
# YOUR GENUINE ATTEMPT
# Save this before opening the protected review.

# %% [markdown]
# ## P-B02-L10 - Integrated pipeline defense
#
# **Your task:** Build full local pipeline; first run must demonstrate duplicate-master block, then separate documented good-path rehearsal; save manifest and 2-minute defense.
#
# Before code, write: input/output grain or file contract, critical failure rule, expected validation. After code, save observed result, one changed retry, one failure/recovery note and 60-90 second explain-back.

# %%
# YOUR GENUINE ATTEMPT
# Save this before opening the protected review.

# %% [markdown]
# ## B02 practice defense
# Without lesson/review open, explain: discover -> ingest/parse -> transform -> validate -> merge -> quality gate -> publish -> observe -> rerun. Name what B02 deliberately leaves for C3.
