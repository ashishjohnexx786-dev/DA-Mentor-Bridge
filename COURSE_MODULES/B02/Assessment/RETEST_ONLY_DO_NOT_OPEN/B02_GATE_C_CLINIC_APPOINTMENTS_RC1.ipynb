# %% [markdown]
# # B02 Gate C - Clinic Appointments | RC1
# **Protected independent assessment. Lesson/review/tutorial/AI solving closed.**
#
# Open only after failed/unstable Gate B, second targeted repair, and explicit full-retest assignment.

# %% [markdown]
# ## Required evidence
# 1. explicit input/output/file contract; 2. deterministic multi-file discovery + lineage; 3. reusable decomposition; 4. strict malformed-numeric/schema handling; 5. duplicate master-key detection BEFORE merge; 6. declared many-to-one merge + unmatched-key check; 7. logging + machine-readable validation; 8. final output withheld on critical failure; 9. safe rerun/idempotence evidence; 10. run manifest with runtime versions/input list/row counts/checks/output; 11. concise engineering defense and C3-boundary explanation.

# %%
# YOUR INDEPENDENT GATE BUILD
# Save genuine attempt before opening Gate review.

# %% [markdown]
# ## Mandatory failure/recovery
# The fixture contains a malformed numeric and duplicate master-key trap. Do not silently coerce/drop/dedupe and publish. Demonstrate correct containment/recovery policy and preserve evidence.

# %%
# FAILURE / RECOVERY / VALIDATION EVIDENCE
