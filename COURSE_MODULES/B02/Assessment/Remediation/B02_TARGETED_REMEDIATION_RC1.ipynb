# %% [markdown]
# # B02 Targeted Remediation RC1
# Use only the competency assigned after a failed/weak attempt. Completing repair does NOT automatically unlock Gate B/C.

# %% [markdown]
# ## R01 Script contract - Rebuild main()+explicit paths on changed file.
# Use changed data. Save the original failure, repair evidence and changed retry.

# %%
# TARGETED REPAIR ATTEMPT

# %% [markdown]
# ## R02 Decomposition - Split a giant function into load/transform/validate/publish and state contracts.
# Use changed data. Save the original failure, repair evidence and changed retry.

# %%
# TARGETED REPAIR ATTEMPT

# %% [markdown]
# ## R03 File batch - Repair unsafe discovery and prove lineage/file-count reconciliation.
# Use changed data. Save the original failure, repair evidence and changed retry.

# %%
# TARGETED REPAIR ATTEMPT

# %% [markdown]
# ## R04 Merge safety - Detect fresh duplicate master key before merge; prove many_to_one protection.
# Use changed data. Save the original failure, repair evidence and changed retry.

# %%
# TARGETED REPAIR ATTEMPT

# %% [markdown]
# ## R05 Interface/grain - Normalize changed nested JSON at declared item grain; reconcile counts.
# Use changed data. Save the original failure, repair evidence and changed retry.

# %%
# TARGETED REPAIR ATTEMPT

# %% [markdown]
# ## R06 API boundary - Local/offline response -> status/source validation; no fake empty success.
# Use changed data. Save the original failure, repair evidence and changed retry.

# %%
# TARGETED REPAIR ATTEMPT

# %% [markdown]
# ## R07 Failure containment - Classify fresh bad value/schema failure and block publish.
# Use changed data. Save the original failure, repair evidence and changed retry.

# %%
# TARGETED REPAIR ATTEMPT

# %% [markdown]
# ## R08 Evidence gate - Create log + machine-readable checks; a critical FAIL must have consequence.
# Use changed data. Save the original failure, repair evidence and changed retry.

# %%
# TARGETED REPAIR ATTEMPT

# %% [markdown]
# ## R09 Rerun safety - Prove failed second run does not corrupt previous good output.
# Use changed data. Save the original failure, repair evidence and changed retry.

# %%
# TARGETED REPAIR ATTEMPT

# %% [markdown]
# ## R10 Handoff - Create a concise run manifest + architecture/failure defense for a fresh mini-batch.
# Use changed data. Save the original failure, repair evidence and changed retry.

# %%
# TARGETED REPAIR ATTEMPT
