# %% [markdown]
# # B02 Mini-Lab - Weekly Bridge Batch Pipeline RC1
# Attempt independently after B02-L01..L10. Protected practice review closed.

# %% [markdown]
# ## Build
# Create a small local batch pipeline that: discovers all monthly sales files deterministically; validates file set/schema and source_file lineage; parses numeric/date fields; reconciles 96 rows and source net-sales control; detects duplicate C013 before merge; processes nested/API fixture where instructed; writes run.log + validation_results.json + run_manifest.json; publishes only after critical checks; reruns safely without duplicate business rows.

# %%
# YOUR MINI-LAB BUILD

# %% [markdown]
# ## Required failure/recovery
# Use sales_bad_numeric.csv and sales_missing_column.csv plus the duplicate customer master. Save proof of classification and output withholding/quarantine policy. Do not edit source fixtures to make the run pass.

# %%
# FAILURE / RECOVERY EVIDENCE

# %% [markdown]
# ## Defense
# Explain the pipeline in 2 minutes: contracts, grain, file selection, master cardinality, critical checks, publish gate, rerun behavior, limitation and what C3 will add. PASS requires reproducible evidence, not a polished notebook only.
