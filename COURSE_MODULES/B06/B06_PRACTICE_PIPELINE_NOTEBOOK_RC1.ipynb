# %% [markdown]
# # B06 Integrated Bridge Capstone - Home Services Network
# Guided capstone. Save first attempts. Protected review stays closed until the complete attempt is saved.

# %% [markdown]
# ## 0. Exact working rule
# Run from a clean kernel. Do not hard-code hidden state. Use `Practice_Data/` as input and `outputs/` for learner-generated evidence. Save validation_results.json, run_manifest.json and a log. An unchanged rerun must not duplicate trusted business rows.

# %%
from pathlib import Path
import json, logging, hashlib, platform
import pandas as pd
DATA = Path('Practice_Data')
OUT = Path('outputs')
OUT.mkdir(exist_ok=True)
# Record package/library versions you actually used.

# %% [markdown]
# ## 1. Discover and ingest
# Deterministically discover `service_orders_2026_*.csv`. Add `source_file`. Load customers, current technicians, item rows, JSON lifecycle events, targets, technician history and skills. Save source row counts before transforming.

# %%
# TODO: deterministic file discovery -> load -> source_file lineage -> source_counts
# EXPECTED CONTROL FROM PROVIDED CONTRACT (verify independently): 72 order rows across the supplied monthly files.

# %% [markdown]
# ## 2. Contract validation
# State one-row meaning and keys before joins. Test required columns, parsable numeric/date fields, unique current customer/technician keys, orphan events and duplicate technician effective-date pairs. Critical failures must block trusted publish or be explicitly quarantined.

# %%
# TODO: validation_results = []
# Add checks with: check_id, severity, expected, observed, status, action, owner.

# %% [markdown]
# ## 3. Transform without changing grain accidentally
# Aggregate service_items to service_order_id before joining order-level fees. Use validated many-to-one joins to customer/technician current tables. Create item_value and total_value. Reconcile lower-grain item total independently.

# %%
# TODO: item aggregation -> validated merges -> order-level curated dataframe -> reconciliation evidence

# %% [markdown]
# ## 4. History / SCD handoff
# Build an SCD2-ready technician history output or design evidence using effective dates. Explain business key vs surrogate/version key and how a historical fact would select the correct technician version. Preserve the duplicate-effective-date defect as a quality issue until resolved.

# %%
# TODO: SCD-ready history / effective-from/to design / overlap-duplicate checks

# %% [markdown]
# ## 5. Publish, observe and prove a safe rerun
# Write curated output only after BLOCK controls pass. Save run log, validation_results.json, run_manifest.json and output control totals. Rerun unchanged input and prove no duplicate business keys or accidental append.

# %%
# TODO: trusted publish gate -> outputs -> manifest -> safe rerun proof

# %% [markdown]
# ## 6. Failure recovery
# Run the malformed numeric fixture and duplicate-technician fixture separately. For each: detection -> containment -> root cause evidence -> repair decision -> rerun/backfill -> post-recovery validation -> owner/communication. Do not overwrite the failed evidence.

# %%
# TODO: failure_case_1 BAD_AMOUNT; failure_case_2 duplicate T006

# %% [markdown]
# ## 7. Platform + monitoring evidence
# Using platform_sources.csv and identity_requirements.csv, record connection boundary, storage/compute reasoning, least-privilege identity, freshness schedule, monitoring signals and recovery owner. Do not invent an on-prem gateway for cloud-only sources.

# %%
# TODO: produce a small design/evidence table or JSON artifact; no Fabric tenant is required.

# %% [markdown]
# ## 8. Capstone defense
# Write 8-12 lines: source grains -> SQL/transformation logic -> Python pipeline -> model/history -> warehouse/quality -> platform/access/freshness -> monitoring/recovery -> limitation/next action. Then complete the Evidence_History and Submission sheets in the workbook.

# %%
# TODO: final_defense = '''...'''
